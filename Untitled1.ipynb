# %% [markdown]
# <a href="https://colab.research.google.com/github/moyoshow1-web/my-work/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("STUNDENT PERFORMANCE ANALYZER")
print ("Hussein Aminat moyosore")
age = 38
print (age)
print ("Counselling Education")
m = 80
p = 90
s = 70
total = m + p + s
print (total)
a = 1
b = 1
c = 1
t = a + b + c
print (t)
average = total / t
print (average)
highestscore = 90
print (highestscore)
lowestscore = 70
print (lowestscore)
passed = True
print (passed)
# Out:
# STUNDENT PERFORMANCE ANALYZER
# Hussein Aminat moyosore
# 38
# Counselling Education
# 240
# 3
# 80.0
# 90
# 70
# True
